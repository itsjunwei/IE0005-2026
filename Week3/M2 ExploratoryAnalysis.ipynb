# %% [markdown]
# # Exploratory Data Analysis in Python
#
# Dataset from Kaggle : **"Pokemon with stats"** by *Alberto Barradas*
# Source: https://www.kaggle.com/abcsds/pokemon (requires login)
#
# Inspired by the wonderful EDA on Pokemon Data by [Redwan Huq](http://inmachineswetrust.com/posts/exploring-pokemon-dataset/).
#
# ![Gotta Catch 'Em All!](images/PokemonIntro.png)

# %% [markdown]
# ---
#
# ### Essential Libraries
#
# Let us begin by importing the essential Python Libraries.
#
# > NumPy : Library for Numeric Computations in Python
# > Pandas : Library for Data Acquisition and Preparation
# > Matplotlib : Low-level library for Data Visualization
# > Seaborn : Higher-level library for Data Visualization

# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
"""
Don't do this unless you know what you're doing.
I'm only including this to remove the warning statements that may overflow the notebook
"""
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ---
#
# ### Import the Dataset
#
# The dataset is in CSV format; hence we use the `read_csv` function from Pandas.
# Immediately after importing, take a quick look at the data using the `head` function.

# %%
# Remember that we don't use `header=None` because
# the first row is already a header (column label) row!
pkmndata = pd.read_csv('pokemonData.csv')
pkmndata.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# Description of the dataset, as available on Kaggle, is as follows.
# Learn more : https://en.wikipedia.org/wiki/List_of_Pok%C3%A9mon
#
# > **\#** : ID for each Pokemon (runs from 1 to 721)
# > **Name** : Name of each Pokemon
# > **Type 1** : Each Pokemon has a basic Type, this determines weakness/resistance to attacks
# > **Type 2** : Some Pokemons are dual type and have a Type 2 value (set to nan otherwise)
# > **Total** : Sum of all stats of a Pokemon, a general guide to how strong a Pokemon is
# > **HP** : Hit Points, defines how much damage a Pokemon can withstand before fainting
# > **Attack** : The base modifier for normal attacks by the Pokemon (e.g., scratch, punch etc.)
# > **Defense** : The base damage resistance of the Pokemon against normal attacks
# > **SP Atk** : Special Attack, the base modifier for special attacks (e.g. fire blast, bubble beam)
# > **SP Def** : Special Defense, the base damage resistance against special attacks
# > **Speed** : Determines which Pokemon attacks first each round
# > **Generation** : Each Pokemon belongs to a certain Generation
# > **Legendary** : Legendary Pokemons are powerful, rare, and hard to catch
#
# ---
#
# Check the vital statistics of the dataset using the `type` and `shape` attributes.

# %%
print("Data type : ", type(pkmndata))   # Ensure that it is a DF
print("Data dims : ", pkmndata.shape)   # n_rows, n_cols
# Out:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  (800, 13)

# %% [markdown]
# Check the variables (and their types) in the dataset using the `dtypes` attribute.

# %%
# Data types of all the columns
print(pkmndata.dtypes)
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %% [markdown]
# ---
#
# ## Explore the Dataset
#
# Exploring any dataset requires a solid understanding of the domain -- it is Pokemon, in our case.
# We understand the following basics regarding Pokemon, primarily from [Wikipedia](https://en.wikipedia.org/wiki/List_of_Pok%C3%A9mon) and [Bulbapedia](https://bulbapedia.bulbagarden.net/wiki/Generation).
#
# > **Generation** : There are seven generations of Pokemon as of 2018, with 721 till Generation VI (this dataset).
# > **Type** : Every Pokemon has a *primary* type, and some of them also have a *secondary* type -- dual-type ones.
# > **Legendary** : These Pokemons are rare, powerful, and really hard to catch -- there are 38 upto Generation VI.
#
# Way more trivia about Pokemon is available online -- but let's come back and retrieve more information from the data.

# %%
"""
Print a concise summary of a DataFrame. (DataFrame Metadata)

This method prints information about a DataFrame including the 
index dtype and columns, non-NA values and memory usage.
"""

# Information about the Variables
pkmndata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# #### Generations of Pokemon in the Dataset

# %%
"""
.unique() gives the unique values

.value_counts() returns counts of unique values.
    The resulting object will be in descending order so that 
    the first element is the most frequently-occurring element. 

For value_counts(), it tells us the distribution
    For instance, we can tell that generation-wise, it is imbalanced

catplot is a categorical plot (in this case, number of elements per category)
"""

# Generations in the Dataset
print("Number of Generations :", len(pkmndata["Generation"].unique()))

# Pokemons in each Generation
print(pkmndata["Generation"].value_counts())
sb.catplot(y = "Generation", data = pkmndata, kind = "count")
# Out:
# Number of Generations : 6
# Generation
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: count, dtype: int64

# %% [markdown]
# #### Types of Pokemon in the Dataset

# %%
# Primary Types in the Dataset
print("Number of Primary Types :", len(pkmndata["Type 1"].unique()))

# Pokemons of each Primary Type
print(pkmndata["Type 1"].value_counts())
sb.catplot(y = "Type 1", data = pkmndata, kind = "count", height = 4)
# Out:
# Number of Primary Types : 18
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %%
"""
note the dropna() function, that we use to drop NA values
    In this case, some pkmn may be monotype (Type 2 = NA)
"""
# Secondary Types in the Dataset
print("Number of Secondary Types :", len(pkmndata["Type 2"].dropna().unique()))

# Pokemons of each Secondary Type
print(pkmndata["Type 2"].dropna().value_counts())
sb.catplot(y = "Type 2", data = pkmndata, kind = "count", height = 4)
# Out:
# Number of Secondary Types : 18
# Type 2
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Water       14
# Ghost       14
# Ice         14
# Rock        14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: count, dtype: int64

# %%
# Pokemons with a Single Type -- I
singletype_data = pkmndata[pkmndata["Type 2"].isnull()] # If no "Type 2" --> Monotype (Single Type)
print("Pokemons with just Type 1 :", len(singletype_data))
singletype_data.head()
# Out:
# Pokemons with just Type 1 : 386
#     #        Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 4   4  Charmander   Fire    NaN    309  39      52       43       60       50
# 5   5  Charmeleon   Fire    NaN    405  58      64       58       80       65
# 9   7    Squirtle  Water    NaN    314  44      48       65       50       64
# 10  8   Wartortle  Water    NaN    405  59      63       80       65       80
# 11  9   Blastoise  Water    NaN    530  79      83      100       85      105
#
#     Speed  Generation  Legendary
# 4      65           1      False
# 5      80           1      False
# 9      43           1      False
# 10     58           1      False
# 11     78           1      False

# %%
# Pokemons with Dual Types -- I and II
dualtype_data = pkmndata[pkmndata["Type 2"].isnull() == False]  # If not null-Type 2, means have Type 2 --> Dual Type
print("Pokemons with Types 1 and 2 :", len(dualtype_data))
dualtype_data.head()
# Out:
# Pokemons with Types 1 and 2 : 414
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 6  6              Charizard   Fire  Flying    534  78      84       78
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 6      109       85    100           1      False

# %% [markdown]
# #### Types of Pokemon over Generations

# %%
# Primary Type over Generations
sb.catplot(y = 'Type 1', data = pkmndata, col = 'Generation', kind = 'count', col_wrap = 2, height = 4)

# %%
# Secondary Type over Generations
sb.catplot(y = 'Type 2', data = pkmndata, col = 'Generation', kind = 'count', col_wrap = 2, height = 4)

# %% [markdown]
# #### Type distribution of Dual-Type Pokemons

# %%
# Pokemons with Dual Types -- I and II
dualtype_data = pkmndata[pkmndata["Type 2"].isnull() == False]
print("Pokemons with Types 1 and 2 :", len(dualtype_data))

"""
.groupby(['Type 1', 'Type 2']).size().unstack()
    Group the data by both types, count how many exist in each pair,
    and pivot into a grid

.heatmap
    uses color intensity to show density. 
    Darker squares = common combinations
    Empty squares = combination doesn't exist in pkmn yet

We have 18 Type 1s and 18 Type 2s --> 18 x 18 = 324 combinations
Bar chart with 300+ bars would be unreadable
Heatmap (grid) here would be easier to scan for patterns 
"""

# Distribution of the Two Types
f = plt.figure(figsize=(6, 6))
sb.heatmap(dualtype_data.groupby(['Type 1', 'Type 2']).size().unstack(), 
           linewidths = 1, annot = True, annot_kws = {"size": 8}, cmap = "BuGn")
# Out:
# Pokemons with Types 1 and 2 : 414
# <Axes: xlabel='Type 2', ylabel='Type 1'>

# %%
# Distribution of the Two Types over Generations
f, axes = plt.subplots(3, 2, figsize=(12, 18))

dualtype_gen1 = dualtype_data[dualtype_data["Generation"] == 1]
dualtype_gen2 = dualtype_data[dualtype_data["Generation"] == 2]
dualtype_gen3 = dualtype_data[dualtype_data["Generation"] == 3]
dualtype_gen4 = dualtype_data[dualtype_data["Generation"] == 4]
dualtype_gen5 = dualtype_data[dualtype_data["Generation"] == 5]
dualtype_gen6 = dualtype_data[dualtype_data["Generation"] == 6]

sb.heatmap(dualtype_gen1.groupby(['Type 1', 'Type 2']).size().unstack(),
           linewidths = 1, annot = True, annot_kws = {"size": 6}, cmap = "BuGn", ax = axes[0,0])
sb.heatmap(dualtype_gen2.groupby(['Type 1', 'Type 2']).size().unstack(), 
           linewidths = 1, annot = True, annot_kws = {"size": 6}, cmap = "BuGn", ax = axes[0,1])
sb.heatmap(dualtype_gen3.groupby(['Type 1', 'Type 2']).size().unstack(), 
           linewidths = 1, annot = True, annot_kws = {"size": 6}, cmap = "BuGn", ax = axes[1,0])
sb.heatmap(dualtype_gen4.groupby(['Type 1', 'Type 2']).size().unstack(), 
           linewidths = 1, annot = True, annot_kws = {"size": 6}, cmap = "BuGn", ax = axes[1,1])
sb.heatmap(dualtype_gen5.groupby(['Type 1', 'Type 2']).size().unstack(), 
           linewidths = 1, annot = True, annot_kws = {"size": 6}, cmap = "BuGn", ax = axes[2,0])
sb.heatmap(dualtype_gen6.groupby(['Type 1', 'Type 2']).size().unstack(), 
           linewidths = 1, annot = True, annot_kws = {"size": 6}, cmap = "BuGn", ax = axes[2,1])
# Out:
# <Axes: xlabel='Type 2', ylabel='Type 1'>

# %% [markdown]
# #### Legendary Pokemons
#
# ![Legendary Pokemons](images/PokemonLegendary.png)
#
# We understand that there are 65 Legendary Pokemons till Generation 6. Rare, powerful, interesting, and hard to catch. Let's explore them in the dataset.

# %%
# Legendary Pokemons in the Dataset
legnd_data = pkmndata[pkmndata["Legendary"] == True]
print("Number of Legendary Pokemons :", len(legnd_data))

# Legendary Pokemons in each Generation
print(legnd_data["Generation"].value_counts())
sb.catplot(y = "Generation", data = legnd_data, kind = "count", height = 4)
# Out:
# Number of Legendary Pokemons : 65
# Generation
# 3    18
# 5    15
# 4    13
# 6     8
# 1     6
# 2     5
# Name: count, dtype: int64

# %%
# Legendary Pokemons in the Dataset
legnd_data = pkmndata[pkmndata["Legendary"] == True]
print("Number of Legendary Pokemons :", len(legnd_data))

# Legendary Pokemons in each Primary Type
print(legnd_data["Type 1"].value_counts())
sb.catplot(y = "Type 1", data = legnd_data, kind = "count", 
           order = legnd_data["Type 1"].value_counts().index, height = 4)
# Out:
# Number of Legendary Pokemons : 65
# Type 1
# Psychic     14
# Dragon      12
# Fire         5
# Electric     4
# Water        4
# Rock         4
# Steel        4
# Ground       4
# Grass        3
# Ice          2
# Normal       2
# Ghost        2
# Dark         2
# Flying       2
# Fairy        1
# Name: count, dtype: int64

# %%
# Legendary Pokemons with two Types -- I and II
dualtype_legnd_data = legnd_data[legnd_data["Type 2"].isnull() == False]
print("Legendary Pokemons with Types 1 and 2 :", len(dualtype_legnd_data))


# Distribution over the Two Types
f = plt.figure(figsize=(8, 8))
sb.heatmap(dualtype_legnd_data.groupby(['Type 1', 'Type 2']).size().unstack(), 
           linewidths = 1, annot = True, annot_kws = {"size": 9}, cmap = "BuGn")
# Out:
# Legendary Pokemons with Types 1 and 2 : 40
# <Axes: xlabel='Type 2', ylabel='Type 1'>

# %% [markdown]
# #### Statistical Summary of Pokemon Points

# %% [markdown]
# Numerical Data
#
# To understand the distribution of stats (HP, Attk, Spd, etc.)

# %%
# Extract only the numeric data variables
numeric_data = pd.DataFrame(pkmndata[["HP", "Attack", "Defense", "Sp. Atk", "Sp. Def", "Speed"]])

# Summary Statistics for all Variables
numeric_data.describe().round(2)
# Out:
#            HP  Attack  Defense  Sp. Atk  Sp. Def   Speed
# count  800.00  800.00   800.00   800.00   800.00  800.00
# mean    69.26   79.00    73.84    72.82    71.90   68.28
# std     25.53   32.46    31.18    32.72    27.83   29.06
# min      1.00    5.00     5.00    10.00    20.00    5.00
# 25%     50.00   55.00    50.00    49.75    50.00   45.00
# 50%     65.00   75.00    70.00    65.00    70.00   65.00
# 75%     80.00  100.00    90.00    95.00    90.00   90.00
# max    255.00  190.00   230.00   194.00   230.00  180.00

# %%
"""
Plot the "Big Three" plots

Boxplot
    Show the quartiles. The box is the middle 50% of Pokemon. The whiskers show
    the range. Dots outside are outliers
    
Histogram
    Shows the frequency. Is the data "normal" (bell curve) etc.
    
Violin Plot
    Combination of the two. Shows density (fat part = common values)
"""

# Draw the distributions of all variables
f, axes = plt.subplots(6, 3, figsize=(18, 24))

count = 0
for var in numeric_data:
    sb.boxplot(data = numeric_data[var], orient = "h", ax = axes[count,0])
    sb.histplot(data = numeric_data[var], ax = axes[count,1])
    sb.violinplot(data = numeric_data[var], orient = "h", ax = axes[count,2])
    count += 1

# %%
"""
.corr() measures linear relationships between -1 and 1

Remember: Heatmap is a clearer visualization of the correlation matrix (Useful figure)
"""
# Correlation Matrix
print(numeric_data.corr())

# Heatmap of the Correlation Matrix
f = plt.figure(figsize=(6, 6))
sb.heatmap(numeric_data.corr(), vmin = -1, vmax = 1, linewidths = 1,
           annot = True, fmt = ".2f", annot_kws = {"size": 8}, cmap = "RdBu")
# Out:
#                HP    Attack   Defense   Sp. Atk   Sp. Def     Speed
# HP       1.000000  0.422386  0.239622  0.362380  0.378718  0.175952
# Attack   0.422386  1.000000  0.438687  0.396362  0.263990  0.381240
# Defense  0.239622  0.438687  1.000000  0.223549  0.510747  0.015227
# Sp. Atk  0.362380  0.396362  0.223549  1.000000  0.506121  0.473018
# Sp. Def  0.378718  0.263990  0.510747  0.506121  1.000000  0.259133
# Speed    0.175952  0.381240  0.015227  0.473018  0.259133  1.000000
# <Axes: >

# %%
# Draw pairs of variables against one another
sb.pairplot(data = numeric_data)

# %% [markdown]
# ### Cleaning the Dataset (Pre-processing)

# %% [markdown]
# #### Unique Names and IDs of Pokemons

# %%
# Names of Pokemon in the Dataset
# .unique() gets a list of all distinct names (removes repeats)
# len() counts how many items are in that list
print("Unique Names of Pokemon :", len(pkmndata["Name"].unique()))
# Out:
# Unique Names of Pokemon : 800

# %%
# IDs of Pokemon in the Dataset
# We do the same check for IDs (column "#")
print("Unique IDs of Pokemon :", len(pkmndata["#"].unique()))
# Out:
# Unique IDs of Pokemon : 721

# %%
# pkmndata.duplicated("#", keep = False) 
# This scans the "#" column. If an ID appears more than once, it marks ALL of them as True.
# keep=False is crucial: it grabs the original AND the duplicate, not just the extra copy.

dupid_data = pkmndata[pkmndata.duplicated("#", keep = False)]

# sort_values(by = "Name") organizes them alphabetically so we can read them easily.
# .head(n = 10) shows us just the first 10 rows to verify it worked.
dupid_data.sort_values(by = "Name").head(n = 10)
# Out:
#        #                       Name Type 1  Type 2  Total  HP  Attack  \
# 510  460                  Abomasnow  Grass     Ice    494  90      92
# 511  460    AbomasnowMega Abomasnow  Grass     Ice    594  90     132
# 392  359                      Absol   Dark     NaN    465  65     130
# 393  359            AbsolMega Absol   Dark     NaN    565  65     150
# 750  681       AegislashBlade Forme  Steel   Ghost    520  60     150
# 751  681      AegislashShield Forme  Steel   Ghost    520  60      50
# 153  142                 Aerodactyl   Rock  Flying    515  80     105
# 154  142  AerodactylMega Aerodactyl   Rock  Flying    615  80     135
# 332  306                     Aggron  Steel    Rock    530  70     110
# 333  306          AggronMega Aggron  Steel     NaN    630  70     140
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 510       75       92       85     60           4      False
# 511      105      132      105     30           4      False
# 392       60       75       60     75           3      False
# 393       60      115       60    115           3      False
# 750       50      150       50     60           6      False
# 751      150       50      150     60           6      False
# 153       65       60       75    130           1      False
# 154       85       70       95    150           1      False
# 332      180       60       60     50           3      False
# 333      230       60       80     50           3      False

# %%
# Count the raw number of rows that are duplicates
print("Pokemons with Duplicate IDs :", len(dupid_data))

# Get a list of the specific ID numbers that are repeated
dupids = dupid_data["#"].unique()
print("Unique Pokemons with DupIDs :", len(dupids))
print()

print("# \t Count \t List of Pokemons with Duplicate IDs")
print()

# This runs once for every problem ID found.
for dupid in dupids:
    
    # Find the rows in our duplicate list that match the current ID number
    # Grab the "Name" column from those rows and turn it into a list
    dupid_list = list(dupid_data[dupid_data["#"] == dupid]["Name"])

    print(dupid, "\t", len(dupid_list), "\t", dupid_list)
# Out:
# Pokemons with Duplicate IDs : 144
# Unique Pokemons with DupIDs : 65
#
# # 	 Count 	 List of Pokemons with Duplicate IDs
#
# 3 	 2 	 ['Venusaur', 'VenusaurMega Venusaur']
# 6 	 3 	 ['Charizard', 'CharizardMega Charizard X', 'CharizardMega Charizard Y']
# 9 	 2 	 ['Blastoise', 'BlastoiseMega Blastoise']
# 15 	 2 	 ['Beedrill', 'BeedrillMega Beedrill']
# 18 	 2 	 ['Pidgeot', 'PidgeotMega Pidgeot']
# 65 	 2 	 ['Alakazam', 'AlakazamMega Alakazam']
# 80 	 2 	 ['Slowbro', 'SlowbroMega Slowbro']
# 94 	 2 	 ['Gengar', 'GengarMega Gengar']
# 115 	 2 	 ['Kangaskhan', 'KangaskhanMega Kangaskhan']
# 127 	 2 	 ['Pinsir', 'PinsirMega Pinsir']
# 130 	 2 	 ['Gyarados', 'GyaradosMega Gyarados']
# 142 	 2 	 ['Aerodactyl', 'AerodactylMega Aerodactyl']
# 150 	 3 	 ['Mewtwo', 'MewtwoMega Mewtwo X', 'MewtwoMega Mewtwo Y']
# 181 	 2 	 ['Ampharos', 'AmpharosMega Ampharos']
# 208 	 2 	 ['Steelix', 'SteelixMega Steelix']
# 212 	 2 	 ['Scizor', 'ScizorMega Scizor']
# 214 	 2 	 ['Heracross', 'HeracrossMega Heracross']
# 229 	 2 	 ['Houndoom', 'HoundoomMega Houndoom']
# 248 	 2 	 ['Tyranitar', 'TyranitarMega Tyranitar']
# 254 	 2 	 ['Sceptile', 'SceptileMega Sceptile']
# 257 	 2 	 ['Blaziken', 'BlazikenMega Blaziken']
# 260 	 2 	 ['Swampert', 'SwampertMega Swampert']
# 282 	 2 	 ['Gardevoir', 'GardevoirMega Gardevoir']
# 302 	 2 	 ['Sableye', 'SableyeMega Sableye']
# 303 	 2 	 ['Mawile', 'MawileMega Mawile']
# 306 	 2 	 ['Aggron', 'AggronMega Aggron']
# 308 	 2 	 ['Medicham', 'MedichamMega Medicham']
# 310 	 2 	 ['Manectric', 'ManectricMega Manectric']
# 319 	 2 	 ['Sharpedo', 'SharpedoMega Sharpedo']
# 323 	 2 	 ['Camerupt', 'CameruptMega Camerupt']
# 334 	 2 	 ['Altaria', 'AltariaMega Altaria']
# 354 	 2 	 ['Banette', 'BanetteMega Banette']
# 359 	 2 	 ['Absol', 'AbsolMega Absol']
# 362 	 2 	 ['Glalie', 'GlalieMega Glalie']
# 373 	 2 	 ['Salamence', 'SalamenceMega Salamence']
# 376 	 2 	 ['Metagross', 'MetagrossMega Metagross']
# 380 	 2 	 ['Latias', 'LatiasMega Latias']
# 381 	 2 	 ['Latios', 'LatiosMega Latios']
# 382 	 2 	 ['Kyogre', 'KyogrePrimal Kyogre']
# 383 	 2 	 ['Groudon', 'GroudonPrimal Groudon']
# 384 	 2 	 ['Rayquaza', 'RayquazaMega Rayquaza']
# 386 	 4 	 ['DeoxysNormal Forme', 'DeoxysAttack Forme', 'DeoxysDefense Forme', 'DeoxysSpeed Forme']
# 413 	 3 	 ['WormadamPlant Cloak', 'WormadamSandy Cloak', 'WormadamTrash Cloak']
# 428 	 2 	 ['Lopunny', 'LopunnyMega Lopunny']
# 445 	 2 	 ['Garchomp', 'GarchompMega Garchomp']
# 448 	 2 	 ['Lucario', 'LucarioMega Lucario']
# 460 	 2 	 ['Abomasnow', 'AbomasnowMega Abomasnow']
# 475 	 2 	 ['Gallade', 'GalladeMega Gallade']
# 479 	 6 	 ['Rotom', 'RotomHeat Rotom', 'RotomWash Rotom', 'RotomFrost Rotom', 'RotomFan Rotom', 'RotomMow Rotom']
# 487 	 2 	 ['GiratinaAltered Forme', 'GiratinaOrigin Forme']
# 492 	 2 	 ['ShayminLand Forme', 'ShayminSky Forme']
# 531 	 2 	 ['Audino', 'AudinoMega Audino']
# 555 	 2 	 ['DarmanitanStandard Mode', 'DarmanitanZen Mode']
# 641 	 2 	 ['TornadusIncarnate Forme', 'TornadusTherian Forme']
# 642 	 2 	 ['ThundurusIncarnate Forme', 'ThundurusTherian Forme']
# 645 	 2 	 ['LandorusIncarnate Forme', 'LandorusTherian Forme']
# 646 	 3 	 ['Kyurem', 'KyuremBlack Kyurem', 'KyuremWhite Kyurem']
# 647 	 2 	 ['KeldeoOrdinary Forme', 'KeldeoResolute Forme']
# 648 	 2 	 ['MeloettaAria Forme', 'MeloettaPirouette Forme']
# 678 	 2 	 ['MeowsticMale', 'MeowsticFemale']
# 681 	 2 	 ['AegislashBlade Forme', 'AegislashShield Forme']
# 710 	 4 	 ['PumpkabooAverage Size', 'PumpkabooSmall Size', 'PumpkabooLarge Size', 'PumpkabooSuper Size']
# 711 	 4 	 ['GourgeistAverage Size', 'GourgeistSmall Size', 'GourgeistLarge Size', 'GourgeistSuper Size']
# 719 	 2 	 ['Diancie', 'DiancieMega Diancie']
# 720 	 2 	 ['HoopaHoopa Confined', 'HoopaHoopa Unbound']

# %% [markdown]
# ---
#
# ## Clean the Dataset
#
# Once we are done with the basic exploration of variables, it's time to *clean* and *tidy-up* the dataset.

# %%
"""
To make the column names consistent and easier to type later 
(e.g., removing spaces and capitalization).

In Python, you can access columns using dot notation (e.g., df.Name). 
If a column has a space (df.Sp Atk), that syntax breaks. 
Underscores prevent syntax errors.
"""

# Create a copy of the Dataset
# .copy() is crucial! It ensures we don't accidentally mess up the original raw data
# if we make a mistake. We work on the "clean" version only.
pkmndata_clean = pkmndata.copy()

# Rename "#" to "ID" of Pokemon
# inplace=True means "save this change directly into pkmndata_clean", 
# rather than creating a new table.
pkmndata_clean.rename(columns = {'#': 'ID'}, inplace = True)

# Convert all Variable Names to UPPERCASE
# .str is an accessor that lets us treat the column names like text strings.
pkmndata_clean.columns = pkmndata_clean.columns.str.upper()

# Remove all spaces and dots from Variable Names
# We replace dots "." with nothing "" (deleting them).
# We replace spaces " " with underscores "_" (snake_case).
# Result: "Sp. Atk" becomes "SP_ATK". Much easier to code with!
pkmndata_clean.columns = pkmndata_clean.columns.str.replace(".","")
pkmndata_clean.columns = pkmndata_clean.columns.str.replace(" ","_")

# Print the Variable Information to check
pkmndata_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          800 non-null    int64
#  1   NAME        800 non-null    object
#  2   TYPE_1      800 non-null    object
#  3   TYPE_2      414 non-null    object
#  4   TOTAL       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   ATTACK      800 non-null    int64
#  7   DEFENSE     800 non-null    int64
#  8   SP_ATK      800 non-null    int64
#  9   SP_DEF      800 non-null    int64
#  10  SPEED       800 non-null    int64
#  11  GENERATION  800 non-null    int64
#  12  LEGENDARY   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# #### Fix Pokemon Names
#
# We take cue from the Pokedex dataset (https://pokemondb.net/pokedex/all), and perform the following (not in order).
#
# > Convert `[Name]Mega [Name]` to `[Name]Mega`
# > Convert `[Name]Mega [Name] X` to `[Name]MegaX`
# > Convert `[Name]Mega [Name] Y` to `[Name]MegaY`
# > Convert `[Name][Form] Forme` to `[Name][Form]`
# > Convert `[Name][Cloak] Cloak` to `[Name][Cloak]`
# > Convert `[Name][Rotom] Rotom` to `[Name][Rotom]`
# > Convert `[Name][Size] Size` to `[Name][Size]`
# > Convert `HoopaHoopa [Form]` to `Hoopa[Form]`
#
# Regular Expression (RegEx) search-and-replace is a lovely tool to accomplish such tasks. We use `re` library in Python.

# %%
"""
This is like "Find and Replace" on steroids. 
Concept: re.sub(pattern, replacement, text) looks for a pattern and swaps it out.

This block is complex. You don't need to memorize the Regex syntax per se.
Focus on our goal:
    Telling the script to spot patterns (e.g., words ending in `Forme`) 
    and chop them off
"""
# Fix the weird Names of Pokemons
import re # "re" is the library for Regular Expressions

# LAMBDA EXPLANATION:
# .apply(lambda x: ...) tells Python: "Take every single name (x) in this column,
# run this specific cleanup function on it, and put the result back."

# REGEX EXPLANATION: r'(.+)(Forme)'
# (.+) means "Group 1: Any text" (e.g., "Venusaur")
# (Forme) means "Group 2: The word Forme"
# r'\1' means "Replace the whole thing with just Group 1".
# Result: "VenusaurForme" becomes "Venusaur".

# Fix names with extra Extensions (removing "Forme", "Cloak", "Rotom", "Size")
pkmndata_clean["NAME"] = pkmndata_clean["NAME"].apply(lambda x: re.sub(r'(.+)(Forme)',r'\1', x))
pkmndata_clean["NAME"] = pkmndata_clean["NAME"].apply(lambda x: re.sub(r'(.+)(Cloak)',r'\1', x))
pkmndata_clean["NAME"] = pkmndata_clean["NAME"].apply(lambda x: re.sub(r'(.+)(Rotom)',r'\1', x))
pkmndata_clean["NAME"] = pkmndata_clean["NAME"].apply(lambda x: re.sub(r'(.+)(Size)',r'\1', x))

# Special case for Hoopa: Keep the SECOND part (Group 2)
# r'(Hoopa)(.+)' -> Keep Group 2 (\2).
pkmndata_clean["NAME"] = pkmndata_clean["NAME"].apply(lambda x: re.sub(r'(Hoopa)(.+)',r'\2', x))

# Fix names with Mega in between
# Example: "VenusaurMega Venusaur" -> Keep "VenusaurMega"
pkmndata_clean["NAME"] = pkmndata_clean["NAME"].apply(lambda x: re.sub(r'(.+Mega)(.+)',r'\1', x))

# Remove Blanks from all the Names
# \s+ matches one or more empty spaces. We replace them with '' (nothing).
pkmndata_clean["NAME"] = pkmndata_clean["NAME"].apply(lambda x: re.sub(r'\s+','', x))

# %%
# Pokemons with Duplicate IDs
# We filter for IDs that appear more than once.
dupid_data_clean = pkmndata_clean[pkmndata_clean.duplicated("ID", keep = False)]
print("Pokemons with Duplicate IDs :", len(dupid_data_clean))

# Get the list of unique IDs that are still duplicated
dupids_clean = dupid_data_clean["ID"].unique()
print("Unique Pokemons with DupIDs :", len(dupids_clean))
print()

# Group Pokemons with same ID (Printing the report)
print("# \t Count \t List of Pokemons with Duplicate IDs")
print()
for dupid_clean in dupids_clean:
    # Print the name list for each duplicate ID to see what remains
    dupid_list_clean = list(dupid_data_clean[dupid_data_clean["ID"] == dupid_clean]["NAME"])
    print(dupid_clean, "\t", len(dupid_list_clean), "\t", dupid_list_clean)
# Out:
# Pokemons with Duplicate IDs : 144
# Unique Pokemons with DupIDs : 65
#
# # 	 Count 	 List of Pokemons with Duplicate IDs
#
# 3 	 2 	 ['Venusaur', 'VenusaurMega']
# 6 	 3 	 ['Charizard', 'CharizardMega', 'CharizardMega']
# 9 	 2 	 ['Blastoise', 'BlastoiseMega']
# 15 	 2 	 ['Beedrill', 'BeedrillMega']
# 18 	 2 	 ['Pidgeot', 'PidgeotMega']
# 65 	 2 	 ['Alakazam', 'AlakazamMega']
# 80 	 2 	 ['Slowbro', 'SlowbroMega']
# 94 	 2 	 ['Gengar', 'GengarMega']
# 115 	 2 	 ['Kangaskhan', 'KangaskhanMega']
# 127 	 2 	 ['Pinsir', 'PinsirMega']
# 130 	 2 	 ['Gyarados', 'GyaradosMega']
# 142 	 2 	 ['Aerodactyl', 'AerodactylMega']
# 150 	 3 	 ['Mewtwo', 'MewtwoMega', 'MewtwoMega']
# 181 	 2 	 ['Ampharos', 'AmpharosMega']
# 208 	 2 	 ['Steelix', 'SteelixMega']
# 212 	 2 	 ['Scizor', 'ScizorMega']
# 214 	 2 	 ['Heracross', 'HeracrossMega']
# 229 	 2 	 ['Houndoom', 'HoundoomMega']
# 248 	 2 	 ['Tyranitar', 'TyranitarMega']
# 254 	 2 	 ['Sceptile', 'SceptileMega']
# 257 	 2 	 ['Blaziken', 'BlazikenMega']
# 260 	 2 	 ['Swampert', 'SwampertMega']
# 282 	 2 	 ['Gardevoir', 'GardevoirMega']
# 302 	 2 	 ['Sableye', 'SableyeMega']
# 303 	 2 	 ['Mawile', 'MawileMega']
# 306 	 2 	 ['Aggron', 'AggronMega']
# 308 	 2 	 ['Medicham', 'MedichamMega']
# 310 	 2 	 ['Manectric', 'ManectricMega']
# 319 	 2 	 ['Sharpedo', 'SharpedoMega']
# 323 	 2 	 ['Camerupt', 'CameruptMega']
# 334 	 2 	 ['Altaria', 'AltariaMega']
# 354 	 2 	 ['Banette', 'BanetteMega']
# 359 	 2 	 ['Absol', 'AbsolMega']
# 362 	 2 	 ['Glalie', 'GlalieMega']
# 373 	 2 	 ['Salamence', 'SalamenceMega']
# 376 	 2 	 ['Metagross', 'MetagrossMega']
# 380 	 2 	 ['Latias', 'LatiasMega']
# 381 	 2 	 ['Latios', 'LatiosMega']
# 382 	 2 	 ['Kyogre', 'KyogrePrimalKyogre']
# 383 	 2 	 ['Groudon', 'GroudonPrimalGroudon']
# 384 	 2 	 ['Rayquaza', 'RayquazaMega']
# 386 	 4 	 ['DeoxysNormal', 'DeoxysAttack', 'DeoxysDefense', 'DeoxysSpeed']
# 413 	 3 	 ['WormadamPlant', 'WormadamSandy', 'WormadamTrash']
# 428 	 2 	 ['Lopunny', 'LopunnyMega']
# 445 	 2 	 ['Garchomp', 'GarchompMega']
# 448 	 2 	 ['Lucario', 'LucarioMega']
# 460 	 2 	 ['Abomasnow', 'AbomasnowMega']
# 475 	 2 	 ['Gallade', 'GalladeMega']
# 479 	 6 	 ['Rotom', 'RotomHeat', 'RotomWash', 'RotomFrost', 'RotomFan', 'RotomMow']
# 487 	 2 	 ['GiratinaAltered', 'GiratinaOrigin']
# 492 	 2 	 ['ShayminLand', 'ShayminSky']
# 531 	 2 	 ['Audino', 'AudinoMega']
# 555 	 2 	 ['DarmanitanStandardMode', 'DarmanitanZenMode']
# 641 	 2 	 ['TornadusIncarnate', 'TornadusTherian']
# 642 	 2 	 ['ThundurusIncarnate', 'ThundurusTherian']
# 645 	 2 	 ['LandorusIncarnate', 'LandorusTherian']
# 646 	 3 	 ['Kyurem', 'KyuremBlackKyurem', 'KyuremWhiteKyurem']
# 647 	 2 	 ['KeldeoOrdinary', 'KeldeoResolute']
# 648 	 2 	 ['MeloettaAria', 'MeloettaPirouette']
# 678 	 2 	 ['MeowsticMale', 'MeowsticFemale']
# 681 	 2 	 ['AegislashBlade', 'AegislashShield']
# 710 	 4 	 ['PumpkabooAverage', 'PumpkabooSmall', 'PumpkabooLarge', 'PumpkabooSuper']
# 711 	 4 	 ['GourgeistAverage', 'GourgeistSmall', 'GourgeistLarge', 'GourgeistSuper']
# 719 	 2 	 ['Diancie', 'DiancieMega']
# 720 	 2 	 ['HoopaConfined', 'HoopaUnbound']

# %%
"""
Objective: Some errors are too specific for a pattern (RegEx). 
We must fix them manually. 

Problem: Charizard Mega X and Mega Y might have been named identically 
in the raw data, or stripped too aggressively.
"""

# X,Y labels missing for Charizard (6) and Mewtwo (150)
print(pkmndata_clean[pkmndata_clean["ID"] == 6]["NAME"])
print(pkmndata_clean[pkmndata_clean["ID"] == 150]["NAME"])
# Out:
# 6        Charizard
# 7    CharizardMega
# 8    CharizardMega
# Name: NAME, dtype: object
# 162        Mewtwo
# 163    MewtwoMega
# 164    MewtwoMega
# Name: NAME, dtype: object

# %%
# .loc[row_index, column_name] = new_value
# Note: The numbers 7, 8, 163, 164 are the ROW NUMBERS (Index), not the Pokemon ID.
# We are manually typing in the correct names to distinguish X from Y.

# Fix the X,Y labels for Charizard and Mewtwo
pkmndata_clean.loc[7,"NAME"] = "CharizardMegaX"
pkmndata_clean.loc[8,"NAME"] = "CharizardMegaY"
pkmndata_clean.loc[163,"NAME"] = "MewtwoMegaX"
pkmndata_clean.loc[164,"NAME"] = "MewtwoMegaY"

# %%
# Set NAME as the Index of the DataFrame
# Before: Rows were labeled 0, 1, 2, 3...
# After: Rows are labeled "Bulbasaur", "Ivysaur", "Venusaur"...
# This makes lookups easier (e.g., data.loc["Pikachu"]).
pkmndata_clean = pkmndata_clean.set_index('NAME')

# Print the DataFrame to check
# .sample(n=10) grabs 10 random rows. 
# It's sometimes better than .head() because it shows you data from the middle/end too.
pkmndata_clean.sample(n = 10)
# Out:
#                  ID    TYPE_1    TYPE_2  TOTAL   HP  ATTACK  DEFENSE  SP_ATK  \
# NAME
# Floatzel        419     Water       NaN    495   85     105       55      85
# DeoxysDefense   386   Psychic       NaN    600   50      70      160      70
# Chesnaught      652     Grass  Fighting    530   88     107      122      74
# KeldeoOrdinary  647     Water  Fighting    580   91      72       90     129
# Starmie         121     Water   Psychic    520   60      75       85     100
# Relicanth       369     Water      Rock    485  100      90      130      45
# Goodra          706    Dragon       NaN    600   90     100       70     110
# Xatu            178   Psychic    Flying    470   65      75       70      95
# Hawlucha        701  Fighting    Flying    500   78      92       75      74
# Ambipom         424    Normal       NaN    482   75     100       66      60
#
#                 SP_DEF  SPEED  GENERATION  LEGENDARY
# NAME
# Floatzel            50    115           4      False
# DeoxysDefense      160     90           3       True
# Chesnaught          75     64           6      False
# KeldeoOrdinary      90    108           5      False
# Starmie             85    115           1      False
# Relicanth           65     55           3      False
# Goodra             150     80           6      False
# Xatu                70     95           2      False
# Hawlucha            63    118           6      False
# Ambipom             66    115           4      False

# %%
# Check the Variable Information
# Confirming everything is the right data type and shape.
pkmndata_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, Bulbasaur to Volcanion
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          800 non-null    int64
#  1   TYPE_1      800 non-null    object
#  2   TYPE_2      414 non-null    object
#  3   TOTAL       800 non-null    int64
#  4   HP          800 non-null    int64
#  5   ATTACK      800 non-null    int64
#  6   DEFENSE     800 non-null    int64
#  7   SP_ATK      800 non-null    int64
#  8   SP_DEF      800 non-null    int64
#  9   SPEED       800 non-null    int64
#  10  GENERATION  800 non-null    int64
#  11  LEGENDARY   800 non-null    bool
# dtypes: bool(1), int64(9), object(2)
# memory usage: 75.8+ KB

# %% [markdown]
# #### Tackle the Missing Values
#
# Note that `TYPE_2` has only 414 values, instead of the overall 800. Let's fill-in the missing values with the string `NoType` for clarity about single/dual types.
#
#
# Missing values are generally represented as `NaN` in numeric arrays, `None` or `NaN` in object arrays, `NaT` in datetime. In certain cases, the missing values may mean the data is not available or not required (as in here). But it may also be errors from data acquisition or data processing. We should check for that.

# %%
# Check missing values in data
# .isnull() scans the entire table and puts 
# "True" if a cell is empty (NaN) and "False" if it has data.
# .sum() counts all the "True" values per column.
pkmndata_clean.isnull().sum()
# Out:
# ID              0
# TYPE_1          0
# TYPE_2        386
# TOTAL           0
# HP              0
# ATTACK          0
# DEFENSE         0
# SP_ATK          0
# SP_DEF          0
# SPEED           0
# GENERATION      0
# LEGENDARY       0
# dtype: int64

# %%
"""
Instead of deleting Pokemon that don't have a second type 
(which would delete half our data), we label them explicitly.
"""

# Fill missing values in data
# .fillna() stands for "Fill N/A" (Fill Not Available).
# value="NoType": We are replacing the empty void with the actual text "NoType".
# inplace=True: We are saving this change directly to our main table.
pkmndata_clean["TYPE_2"].fillna(value = "NoType", inplace = True)

# %%
# Check the Clean Dataset
# We run .info() again to see the "Non-Null Count".
# Before: TYPE_2 might have said "414 non-null".
# After: It should say "800 non-null" (matching the Total entries).
pkmndata_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, Bulbasaur to Volcanion
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          800 non-null    int64
#  1   TYPE_1      800 non-null    object
#  2   TYPE_2      800 non-null    object
#  3   TOTAL       800 non-null    int64
#  4   HP          800 non-null    int64
#  5   ATTACK      800 non-null    int64
#  6   DEFENSE     800 non-null    int64
#  7   SP_ATK      800 non-null    int64
#  8   SP_DEF      800 non-null    int64
#  9   SPEED       800 non-null    int64
#  10  GENERATION  800 non-null    int64
#  11  LEGENDARY   800 non-null    bool
# dtypes: bool(1), int64(9), object(2)
# memory usage: 75.8+ KB

# %%
# Check the Variable Information
# .value_counts() counts how many Pokemon belong to each Type 2 category.
# Note: The .dropna() here is actually redundant because we just filled all the N/As! 
# It's likely left over from code before we fixed the data, acting as a safety net.
print(pkmndata_clean["TYPE_2"].dropna().value_counts())
# Out:
# TYPE_2
# NoType      386
# Flying       97
# Ground       35
# Poison       34
# Psychic      33
# Fighting     26
# Grass        25
# Fairy        23
# Steel        22
# Dark         20
# Dragon       18
# Ice          14
# Rock         14
# Water        14
# Ghost        14
# Fire         12
# Electric      6
# Normal        4
# Bug           3
# Name: count, dtype: int64

# %% [markdown]
# ---
#
# ## Pokemons worth Exploring
#
# ![My Favorites](images/PokemonMyFabs.png)
#
# Of course, we all have our favourite Pokemons -- mine are Pikachu, Jigglypuff, Togepi, Bulbasaur and Snorlax -- as you can tell from the image above.

# %%
# My Favorites (entirely based on cuteness index, and not on their power)
pkmndata_clean.loc[["Pikachu", "Jigglypuff", "Togepi", "Bulbasaur", "Snorlax"]]
# Out:
#              ID    TYPE_1  TYPE_2  TOTAL   HP  ATTACK  DEFENSE  SP_ATK  \
# NAME
# Pikachu      25  Electric  NoType    320   35      55       40      50
# Jigglypuff   39    Normal   Fairy    270  115      45       20      45
# Togepi      175     Fairy  NoType    245   35      20       65      40
# Bulbasaur     1     Grass  Poison    318   45      49       49      65
# Snorlax     143    Normal  NoType    540  160     110       65      65
#
#             SP_DEF  SPEED  GENERATION  LEGENDARY
# NAME
# Pikachu         50     90           1      False
# Jigglypuff      25     20           1      False
# Togepi          65     20           2      False
# Bulbasaur       65     45           1      False
# Snorlax        110     30           1      False

# %% [markdown]
# However, there are some other Pokemons worth exploring -- especially the strongest and the weakest Pokemons, may be for each type and generation.
#
# #### Strongest and Weakest Pokemons

# %%
# Strongest Pokemons -- the Top 10
# Ascending = False --> Descending
pkmndata_clean.sort_values('TOTAL', ascending=False).head(10)
# Out:
#                        ID   TYPE_1    TYPE_2  TOTAL   HP  ATTACK  DEFENSE  \
# NAME
# RayquazaMega          384   Dragon    Flying    780  105     180      100
# MewtwoMegaY           150  Psychic    NoType    780  106     150       70
# MewtwoMegaX           150  Psychic  Fighting    780  106     190      100
# KyogrePrimalKyogre    382    Water    NoType    770  100     150       90
# GroudonPrimalGroudon  383   Ground      Fire    770  100     180      160
# Arceus                493   Normal    NoType    720  120     120      120
# KyuremWhiteKyurem     646   Dragon       Ice    700  125     120       90
# KyuremBlackKyurem     646   Dragon       Ice    700  125     170      100
# SalamenceMega         373   Dragon    Flying    700   95     145      130
# MetagrossMega         376    Steel   Psychic    700   80     145      150
#
#                       SP_ATK  SP_DEF  SPEED  GENERATION  LEGENDARY
# NAME
# RayquazaMega             180     100    115           3       True
# MewtwoMegaY              194     120    140           1       True
# MewtwoMegaX              154     100    130           1       True
# KyogrePrimalKyogre       180     160     90           3       True
# GroudonPrimalGroudon     150      90     90           3       True
# Arceus                   120     120    120           4       True
# KyuremWhiteKyurem        170     100     95           5       True
# KyuremBlackKyurem        120      90     95           5       True
# SalamenceMega            120      90    120           3      False
# MetagrossMega            105     110    110           3      False

# %%
# Weakest Pokemons -- the Bottom 10
# Ascending = True --> Low to High
pkmndata_clean.sort_values('TOTAL', ascending=True).head(10)
# Out:
#              ID   TYPE_1  TYPE_2  TOTAL  HP  ATTACK  DEFENSE  SP_ATK  SP_DEF  \
# NAME
# Sunkern     191    Grass  NoType    180  30      30       30      30      30
# Azurill     298   Normal   Fairy    190  50      20       40      20      40
# Kricketot   401      Bug  NoType    194  37      25       41      25      41
# Wurmple     265      Bug  NoType    195  45      45       35      20      30
# Weedle       13      Bug  Poison    195  40      35       30      20      20
# Caterpie     10      Bug  NoType    195  45      30       35      20      20
# Ralts       280  Psychic   Fairy    198  28      25       25      45      35
# Scatterbug  664      Bug  NoType    200  38      35       40      27      25
# Magikarp    129    Water  NoType    200  20      10       55      15      20
# Feebas      349    Water  NoType    200  20      15       20      10      55
#
#             SPEED  GENERATION  LEGENDARY
# NAME
# Sunkern        30           2      False
# Azurill        20           3      False
# Kricketot      25           4      False
# Wurmple        20           3      False
# Weedle         50           1      False
# Caterpie       45           1      False
# Ralts          40           3      False
# Scatterbug     35           6      False
# Magikarp       80           1      False
# Feebas         80           3      False

# %% [markdown]
# #### Strongest and Weakest Pokemons -- Legendary and Non-Legendary

# %%
# Strongest Legendary Pokemons -- the Top 10
pkmndata_clean[pkmndata_clean["LEGENDARY"] == True].sort_values('TOTAL', ascending=False).head(10)
# Out:
#                        ID   TYPE_1    TYPE_2  TOTAL   HP  ATTACK  DEFENSE  \
# NAME
# MewtwoMegaX           150  Psychic  Fighting    780  106     190      100
# MewtwoMegaY           150  Psychic    NoType    780  106     150       70
# RayquazaMega          384   Dragon    Flying    780  105     180      100
# KyogrePrimalKyogre    382    Water    NoType    770  100     150       90
# GroudonPrimalGroudon  383   Ground      Fire    770  100     180      160
# Arceus                493   Normal    NoType    720  120     120      120
# KyuremBlackKyurem     646   Dragon       Ice    700  125     170      100
# LatiasMega            380   Dragon   Psychic    700   80     100      120
# KyuremWhiteKyurem     646   Dragon       Ice    700  125     120       90
# DiancieMega           719     Rock     Fairy    700   50     160      110
#
#                       SP_ATK  SP_DEF  SPEED  GENERATION  LEGENDARY
# NAME
# MewtwoMegaX              154     100    130           1       True
# MewtwoMegaY              194     120    140           1       True
# RayquazaMega             180     100    115           3       True
# KyogrePrimalKyogre       180     160     90           3       True
# GroudonPrimalGroudon     150      90     90           3       True
# Arceus                   120     120    120           4       True
# KyuremBlackKyurem        120      90     95           5       True
# LatiasMega               140     150    110           3       True
# KyuremWhiteKyurem        170     100     95           5       True
# DiancieMega              160     110    110           6       True

# %%
# Weakest Legendary Pokemons -- the Bottom 10
pkmndata_clean[pkmndata_clean["LEGENDARY"] == True].sort_values('TOTAL', ascending=True).head(10)
# Out:
#                      ID    TYPE_1    TYPE_2  TOTAL  HP  ATTACK  DEFENSE  \
# NAME
# Articuno            144       Ice    Flying    580  90      85      100
# Azelf               482   Psychic    NoType    580  75     125       70
# Cobalion            638     Steel  Fighting    580  91      90      129
# Terrakion           639      Rock  Fighting    580  91     129       90
# Virizion            640     Grass  Fighting    580  91      90       72
# TornadusIncarnate   641    Flying    NoType    580  79     115       70
# TornadusTherian     641    Flying    NoType    580  79     100       80
# ThundurusIncarnate  642  Electric    Flying    580  79     115       70
# Mesprit             481   Psychic    NoType    580  80     105      105
# Registeel           379     Steel    NoType    580  80      75      150
#
#                     SP_ATK  SP_DEF  SPEED  GENERATION  LEGENDARY
# NAME
# Articuno                95     125     85           1       True
# Azelf                  125      70    115           4       True
# Cobalion                90      72    108           5       True
# Terrakion               72      90    108           5       True
# Virizion                90     129    108           5       True
# TornadusIncarnate      125      80    111           5       True
# TornadusTherian        110      90    121           5       True
# ThundurusIncarnate     125      80    111           5       True
# Mesprit                105     105     80           4       True
# Registeel               75     150     50           3       True

# %%
# Strongest Non-Legendary Pokemons -- the Top 10
pkmndata_clean[pkmndata_clean["LEGENDARY"] == False].sort_values('TOTAL', ascending=False).head(10)
# Out:
#                  ID  TYPE_1   TYPE_2  TOTAL   HP  ATTACK  DEFENSE  SP_ATK  \
# NAME
# MetagrossMega   376   Steel  Psychic    700   80     145      150     105
# GarchompMega    445  Dragon   Ground    700  108     170      115     120
# SalamenceMega   373  Dragon   Flying    700   95     145      130     120
# TyranitarMega   248    Rock     Dark    700  100     164      150      95
# Slaking         289  Normal   NoType    670  150     160      100      95
# GyaradosMega    130   Water     Dark    640   95     155      109      70
# SwampertMega    260   Water   Ground    635  100     150      110      95
# CharizardMegaY    6    Fire   Flying    634   78     104       78     159
# CharizardMegaX    6    Fire   Dragon    634   78     130      111     130
# BlastoiseMega     9   Water   NoType    630   79     103      120     135
#
#                 SP_DEF  SPEED  GENERATION  LEGENDARY
# NAME
# MetagrossMega      110    110           3      False
# GarchompMega        95     92           4      False
# SalamenceMega       90    120           3      False
# TyranitarMega      120     71           2      False
# Slaking             65    100           3      False
# GyaradosMega       130     81           1      False
# SwampertMega       110     70           3      False
# CharizardMegaY     115    100           1      False
# CharizardMegaX      85    100           1      False
# BlastoiseMega      115     78           1      False

# %%
# Weakest Non-Legendary Pokemons -- the Bottom 10
pkmndata_clean[pkmndata_clean["LEGENDARY"] == False].sort_values('TOTAL', ascending=True).head(10)
# Out:
#              ID   TYPE_1  TYPE_2  TOTAL  HP  ATTACK  DEFENSE  SP_ATK  SP_DEF  \
# NAME
# Sunkern     191    Grass  NoType    180  30      30       30      30      30
# Azurill     298   Normal   Fairy    190  50      20       40      20      40
# Kricketot   401      Bug  NoType    194  37      25       41      25      41
# Weedle       13      Bug  Poison    195  40      35       30      20      20
# Caterpie     10      Bug  NoType    195  45      30       35      20      20
# Wurmple     265      Bug  NoType    195  45      45       35      20      30
# Ralts       280  Psychic   Fairy    198  28      25       25      45      35
# Feebas      349    Water  NoType    200  20      15       20      10      55
# Scatterbug  664      Bug  NoType    200  38      35       40      27      25
# Magikarp    129    Water  NoType    200  20      10       55      15      20
#
#             SPEED  GENERATION  LEGENDARY
# NAME
# Sunkern        30           2      False
# Azurill        20           3      False
# Kricketot      25           4      False
# Weedle         50           1      False
# Caterpie       45           1      False
# Wurmple        20           3      False
# Ralts          40           3      False
# Feebas         80           3      False
# Scatterbug     35           6      False
# Magikarp       80           1      False

# %% [markdown]
# #### Strongest and Weakest Pokemons -- Across Generations

# %%
# Strongest Pokemons in each Generation -- the Top 10
generation = 1
pkmndata_clean[pkmndata_clean["GENERATION"] == generation].sort_values('TOTAL', ascending=False).head(10)
# Out:
#                  ID   TYPE_1    TYPE_2  TOTAL   HP  ATTACK  DEFENSE  SP_ATK  \
# NAME
# MewtwoMegaY     150  Psychic    NoType    780  106     150       70     194
# MewtwoMegaX     150  Psychic  Fighting    780  106     190      100     154
# Mewtwo          150  Psychic    NoType    680  106     110       90     154
# GyaradosMega    130    Water      Dark    640   95     155      109      70
# CharizardMegaX    6     Fire    Dragon    634   78     130      111     130
# CharizardMegaY    6     Fire    Flying    634   78     104       78     159
# BlastoiseMega     9    Water    NoType    630   79     103      120     135
# VenusaurMega      3    Grass    Poison    625   80     100      123     122
# AerodactylMega  142     Rock    Flying    615   80     135       85      70
# Mew             151  Psychic    NoType    600  100     100      100     100
#
#                 SP_DEF  SPEED  GENERATION  LEGENDARY
# NAME
# MewtwoMegaY        120    140           1       True
# MewtwoMegaX        100    130           1       True
# Mewtwo              90    130           1       True
# GyaradosMega       130     81           1      False
# CharizardMegaX      85    100           1      False
# CharizardMegaY     115    100           1      False
# BlastoiseMega      115     78           1      False
# VenusaurMega       120     80           1      False
# AerodactylMega      95    150           1      False
# Mew                100    100           1      False

# %%
# Weakest Pokemons in each Generation -- the Bottom 10
generation = 1
pkmndata_clean[pkmndata_clean["GENERATION"] == generation].sort_values('TOTAL', ascending=True).head(10)
# Out:
#            ID  TYPE_1  TYPE_2  TOTAL  HP  ATTACK  DEFENSE  SP_ATK  SP_DEF  \
# NAME
# Weedle     13     Bug  Poison    195  40      35       30      20      20
# Caterpie   10     Bug  NoType    195  45      30       35      20      20
# Magikarp  129   Water  NoType    200  20      10       55      15      20
# Kakuna     14     Bug  Poison    205  45      25       50      25      25
# Metapod    11     Bug  NoType    205  50      20       55      25      25
# Zubat      41  Poison  Flying    245  40      45       35      30      40
# Pidgey     16  Normal  Flying    251  40      45       40      35      35
# Rattata    19  Normal  NoType    253  30      56       35      25      35
# Spearow    21  Normal  Flying    262  40      60       30      31      31
# Diglett    50  Ground  NoType    265  10      55       25      35      45
#
#           SPEED  GENERATION  LEGENDARY
# NAME
# Weedle       50           1      False
# Caterpie     45           1      False
# Magikarp     80           1      False
# Kakuna       35           1      False
# Metapod      30           1      False
# Zubat        55           1      False
# Pidgey       56           1      False
# Rattata      72           1      False
# Spearow      70           1      False
# Diglett      95           1      False

# %% [markdown]
# #### Strength of Pokemons over various Types

# %%
"""
.groupby(['TYPE_1', 'TYPE_2']):
   Imagine sorting the Pokemon into physical buckets. 
   Bucket 1: "Fire + Flying". Bucket 2: "Grass + Poison".
   It groups rows that share BOTH specific types.

.mean():
   Inside each bucket, calculate the average of the numbers.
   (e.g., Average Attack of all Fire/Flying Pokemon).

.loc[:, 'TOTAL']:
   .loc[rows, columns] -> ":" means "Keep all rows (groups)".
   We select only the "TOTAL" column because we are measuring overall strength.
   Result: A long list showing "Type Pair -> Average Strength".
"""
total_means = pkmndata_clean.groupby(['TYPE_1', 'TYPE_2']).mean().loc[:, 'TOTAL']

"""
Strongest Pokemons in each Pair of Types -- the Top 10

.reset_index():
   The 'groupby' command turned TYPE_1 and TYPE_2 into "Labels" (Index).
   This command turns them back into regular Columns so we can read them easily.

.sort_values('TOTAL', ascending=False):
   Sorts the data by the 'TOTAL' column.
   False means "Descending" (Highest numbers at the top).

.head(10):
   Show only the top 10 strongest pairs.

.round(2):
   Clean up the numbers (e.g., turn 560.333333 into 560.33).
"""
print(total_means.reset_index().sort_values('TOTAL', ascending=False).head(10).round(2))

# Heatmap of Average TOTAL across every pair of TYPEs

f = plt.figure(figsize=(10, 10))
"""
.unstack():
   Our data currently looks like a tall list (Row 1: Fire-Water, Row 2: Fire-Grass).
   .unstack() pivots this list into a Grid/Matrix.
   Now, 'TYPE_1' becomes the rows and 'TYPE_2' becomes the columns.
"""

sb.heatmap(total_means.unstack(), linewidths = 1,
           annot = True, fmt = ".0f", annot_kws = {"size": 8}, cmap = "BuGn")
# Out:
#       TYPE_1    TYPE_2   TOTAL
# 80    Ground      Fire  770.00
# 26    Dragon       Ice  686.67
# 60     Ghost    Dragon  680.00
# 130    Steel    Dragon  680.00
# 21    Dragon  Electric  680.00
# 23    Dragon      Fire  680.00
# 109  Psychic      Dark  680.00
# 118     Rock      Dark  650.00
# 28    Dragon   Psychic  650.00
# 24    Dragon    Flying  641.67
# <Axes: xlabel='TYPE_2', ylabel='TYPE_1'>

# %% [markdown]
# #### Strength of Legendary Pokemons over various Types

# %%
# Compute the Average TOTAL across every pair of TYPEs
total_means = pkmndata_clean[pkmndata_clean["LEGENDARY"] == True].groupby(['TYPE_1', 'TYPE_2']).mean().loc[:, 'TOTAL']

# Strongest Pokemons in each Pair of Types -- the Top 10
print(total_means.reset_index().sort_values('TOTAL', ascending=False).head(10).round(2))

# Heatmap of Average TOTAL across every pair of TYPEs
f = plt.figure(figsize=(10, 10))
sb.heatmap(total_means.unstack(), linewidths = 1,
           annot = True, fmt = ".0f", annot_kws = {"size": 8}, cmap = "BuGn")
# Out:
#      TYPE_1    TYPE_2   TOTAL
# 27  Psychic  Fighting  780.00
# 20   Ground      Fire  770.00
# 4    Dragon    Flying  730.00
# 25   Normal    NoType  695.00
# 6    Dragon       Ice  686.67
# 16    Ghost    Dragon  680.00
# 39    Water    Dragon  680.00
# 35    Steel    Dragon  680.00
# 29  Psychic    Flying  680.00
# 26  Psychic      Dark  680.00
# <Axes: xlabel='TYPE_2', ylabel='TYPE_1'>

# %% [markdown]
# ## Fundamental "first step" of any Data Science or AI project: understanding the data.
#
# ### 1. **Data Acquisition & Inspection**
#
# - Loading Data: Using `pandas.read_csv()` to convert raw files into a structured DataFrame.
#
# - Structure Analysis: Using `.shape`, `.columns`, and `.dtypes` to understand dimensions and data types (Integers vs. Objects/Strings).
#
# - Data Integrity: Using `.info()` to identify missing values (nulls) and memory usage.
#
# ### 2. **Univariate Analysis (One Variable)**
#
# - Categorical Data: Using `.value_counts()` and Bar/Count Plots (`sb.catplot`) to analyze frequency (e.g., How many Pokemon are there per Generation?).
#
# - Numerical Data: Using Histograms (`sb.histplot`) to visualize distribution shapes (Normal vs. Skewed) and Boxplots (`sb.boxplot`) to detect outliers and understand the spread (Quartiles).
#
# - Summary Statistics: Applying `.describe()` to calculate mean, standard deviation, min, and max values.
#
# ### 3. **Data Cleaning & Manipulation**
#
#
# - Handling Missing Data: Using `.dropna()` to handle null values in secondary features (e.g., Pokemon with no "Type 2").
#
# - Filtering: Boolean indexing to isolate specific subsets (e.g., extracting only "Legendary" Pokemon).
#
# - Grouping & Aggregation: Using `.groupby()` to summarize data by categories (e.g., finding the average stats across different Pokemon Types).
#
# ### 4. **Bivariate & Multivariate Analysis (Relationships)**
#
# - Comparisons: Using Boxplots to compare numerical distributions across categories (e.g., Total Stats of Legendary vs. Non-Legendary).
#
# - Correlation: Calculating Pearson correlation coefficients (`.corr()`) to measure linear relationships.
#
# - Heatmaps: Using `sb.heatmap` to visualize the correlation matrix (e.g., seeing if Attack correlates with Defense).
#
# - Multi-variable Visualization: Creating complex Heatmaps to visualize aggregated data (e.g., Average Total Stats for every Type 1 vs. Type 2 combination).
